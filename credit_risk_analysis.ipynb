# %%
import pandas as pd

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("laotse/credit-risk-dataset")

print("Path to dataset files:", path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 import kagglehub
#       3 # Download latest version
#       4 path = kagglehub.dataset_download("laotse/credit-risk-dataset")
#
# ModuleNotFoundError: No module named 'kagglehub'

# %%
{"@context":{"@language":"en","@vocab":"https://schema.org/","citeAs":"cr:citeAs","column":"cr:column","conformsTo":"dct:conformsTo","cr":"http://mlcommons.org/croissant/","data":{"@id":"cr:data","@type":"@json"},"dataBiases":"cr:dataBiases","dataCollection":"cr:dataCollection","dataType":{"@id":"cr:dataType","@type":"@vocab"},"dct":"http://purl.org/dc/terms/","extract":"cr:extract","field":"cr:field","fileProperty":"cr:fileProperty","fileObject":"cr:fileObject","fileSet":"cr:fileSet","format":"cr:format","includes":"cr:includes","isEnumeration":"cr:isEnumeration","jsonPath":"cr:jsonPath","key":"cr:key","md5":"cr:md5","parentField":"cr:parentField","path":"cr:path","personalSensitiveInformation":"cr:personalSensitiveInformation","recordSet":"cr:recordSet","references":"cr:references","regex":"cr:regex","repeated":"cr:repeated","replace":"cr:replace","sc":"https://schema.org/","separator":"cr:separator","source":"cr:source","subField":"cr:subField","transform":"cr:transform","wd":"https://www.wikidata.org/wiki/"},"alternateName":"This dataset contains columns simulating credit bureau data","conformsTo":"http://mlcommons.org/croissant/1.0","license":{"@type":"sc:CreativeWork","name":"CC0: Public Domain","url":"https://creativecommons.org/publicdomain/zero/1.0/"},"distribution":[{"contentUrl":"https://www.kaggle.com/api/v1/datasets/download/laotse/credit-risk-dataset?datasetVersionNumber=1","contentSize":"367.693 KB","md5":"dJmLceXgZ7LWY3v4c6qvDQ==","encodingFormat":"application/zip","@id":"archive.zip","@type":"cr:FileObject","name":"archive.zip","description":"Archive containing all the contents of the Credit Risk Dataset dataset"},{"contentUrl":"credit_risk_dataset.csv","containedIn":{"@id":"archive.zip"},"encodingFormat":"application/vnd.ms-excel","@id":"credit_risk_dataset.csv_fileobject","@type":"cr:FileObject","name":"credit_risk_dataset.csv"}],"recordSet":[{"field":[{"dataType":["sc:Integer"],"source":{"fileObject":{"@id":"credit_risk_dataset.csv_fileobject"},"extract":{"column":"person_age"}},"@id":"credit_risk_dataset.csv/person_age","@type":"cr:Field","name":"person_age"},{"dataType":["sc:Integer"],"source":{"fileObject":{"@id":"credit_risk_dataset.csv_fileobject"},"extract":{"column":"person_income"}},"@id":"credit_risk_dataset.csv/person_income","@type":"cr:Field","name":"person_income"},{"dataType":["sc:Text"],"source":{"fileObject":{"@id":"credit_risk_dataset.csv_fileobject"},"extract":{"column":"person_home_ownership"}},"@id":"credit_risk_dataset.csv/person_home_ownership","@type":"cr:Field","name":"person_home_ownership"},{"dataType":["sc:Float"],"source":{"fileObject":{"@id":"credit_risk_dataset.csv_fileobject"},"extract":{"column":"person_emp_length"}},"@id":"credit_risk_dataset.csv/person_emp_length","@type":"cr:Field","name":"person_emp_length"},{"dataType":["sc:Text"],"source":{"fileObject":{"@id":"credit_risk_dataset.csv_fileobject"},"extract":{"column":"loan_intent"}},"@id":"credit_risk_dataset.csv/loan_intent","@type":"cr:Field","name":"loan_intent"},{"dataType":["sc:Text"],"source":{"fileObject":{"@id":"credit_risk_dataset.csv_fileobject"},"extract":{"column":"loan_grade"}},"@id":"credit_risk_dataset.csv/loan_grade","@type":"cr:Field","name":"loan_grade"},{"dataType":["sc:Integer"],"source":{"fileObject":{"@id":"credit_risk_dataset.csv_fileobject"},"extract":{"column":"loan_amnt"}},"@id":"credit_risk_dataset.csv/loan_amnt","@type":"cr:Field","name":"loan_amnt"},{"dataType":["sc:Float"],"source":{"fileObject":{"@id":"credit_risk_dataset.csv_fileobject"},"extract":{"column":"loan_int_rate"}},"@id":"credit_risk_dataset.csv/loan_int_rate","@type":"cr:Field","name":"loan_int_rate"},{"dataType":["sc:Integer"],"source":{"fileObject":{"@id":"credit_risk_dataset.csv_fileobject"},"extract":{"column":"loan_status"}},"@id":"credit_risk_dataset.csv/loan_status","@type":"cr:Field","name":"loan_status"},{"dataType":["sc:Float"],"source":{"fileObject":{"@id":"credit_risk_dataset.csv_fileobject"},"extract":{"column":"loan_percent_income"}},"@id":"credit_risk_dataset.csv/loan_percent_income","@type":"cr:Field","name":"loan_percent_income"},{"dataType":["sc:Boolean"],"source":{"fileObject":{"@id":"credit_risk_dataset.csv_fileobject"},"extract":{"column":"cb_person_default_on_file"}},"@id":"credit_risk_dataset.csv/cb_person_default_on_file","@type":"cr:Field","name":"cb_person_default_on_file"},{"dataType":["sc:Integer"],"source":{"fileObject":{"@id":"credit_risk_dataset.csv_fileobject"},"extract":{"column":"cb_person_cred_hist_length"}},"@id":"credit_risk_dataset.csv/cb_person_cred_hist_length","@type":"cr:Field","name":"cb_person_cred_hist_length"}],"@id":"credit_risk_dataset.csv","@type":"cr:RecordSet","name":"credit_risk_dataset.csv"}],"version":1,"keywords":["subject \u003E earth and nature","subject \u003E people and society \u003E business \u003E finance \u003E lending"],"isAccessibleForFree":true,"includedInDataCatalog":{"@type":"sc:DataCatalog","name":"Kaggle","url":"https://www.kaggle.com"},"creator":{"@type":"sc:Person","name":"Lao Tse","url":"/laotse","image":"https://storage.googleapis.com/kaggle-avatars/thumbnails/5203538-kg.png"},"publisher":{"@type":"sc:Organization","name":"Kaggle","url":"https://www.kaggle.com/organizations/kaggle","image":"https://storage.googleapis.com/kaggle-organizations/4/thumbnail.png"},"thumbnailUrl":"https://storage.googleapis.com/kaggle-datasets-images/688532/1207035/7416a3cd517a02b18f39c86d5f13aa5f/dataset-card.jpg?t=2020-06-02-07-05-25","dateModified":"2020-06-02T06:10:39.067","datePublished":"2020-06-02T06:13:11.8795786","@type":"sc:Dataset","name":"Credit Risk Dataset","url":"https://www.kaggle.com/datasets/laotse/credit-risk-dataset/versions/1","description":"Detailed data description of Credit Risk dataset:\n| **Feature Name** | **Description** | \n| --- | --- |\n| person_age | Age | \n| person_income | Annual Income | \n| person_home_ownership | Home ownership |\n| person_emp_length | Employment length (in years) | \n| loan_intent | Loan intent |  \n| loan_grade | Loan grade | \n| loan_amnt | Loan amount | \n| loan_int_rate | Interest rate | | \n| loan_status | Loan status (0 is non default 1 is default) | \n| loan_percent_income | Percent income | \n| cb_person_default_on_file | Historical default | \n| cb_preson_cred_hist_length | Credit history length | \n"}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ...

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\cbayr'

# %%
os.listdir()
# Out:
# ['-1.14-windows.xml',
#  '.anaconda',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.opera',
#  '.popsql.json',
#  '.pylint.d',
#  '.python_history',
#  '.spyder-py3',
#  '.vscode',
#  '2023 güz alıştırma.py',
#  '2023 güz alıştırma2.py',
#  '2024 alıştırma.py',
#  '3D Objects',
#  'alıştıma ds6.py',
#  'anaconda3',
#  'Annoml.py',
#  'annomly detection and elimination.py',
#  'AppData',
#  'Application Data',
#  'Applied Machine Learning.py',
#  'Banking Analysis.ipynb',
#  'Belgelerim',
#  'beyzanın scripti.py',
#  'BÜTÜNLEME 2024.py',
#  'codeshare 1.py',
#  'Contacts',
#  'Cookies',
#  'dataframe linkleri.py',
#  'def practice.py',
#  'Documents',
#  'Downloads',
#  'Dropbox',
#  'Dropbox (Old)',
#  'EXAM QUESTIONS.py',
#  'exam.py',
#  'Extra tutorial.py',
#  'Favorites',
#  'Game sales.py',
#  'groupby function.py',
#  'hello.py',
#  'helloworld.py',
#  'HTML1.html',
#  'Jedi',
# ...

# %%
import os
os.getcwd()

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\cbayr\Downloads\archive (5)\credit_risk_dataset.csv")

# %%
df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# ...
